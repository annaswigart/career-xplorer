# %% [markdown]
# # Set up

# %%
# Load needed modules and functions
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

from pylab import figure, show

import pandas as pd
from pandas import DataFrame, Series
from sklearn.neighbors import NearestNeighbors

# %%
#set up path to the data files
import os
data_folder = os.path.join(os.pardir, "data")

# %%
import glob 
file_names = glob.glob(data_folder + "/*")
#file_names = glob.glob(data_folder + "\\\*")

# %%
import re
p = re.compile('data/(.*).txt')
#p = re.compile('data\\\(.*).txt')
name_list = []
for name in file_names:
    frame_name = p.findall(name)[0]
    frame_name = frame_name.lower().replace(" ","_")
    frame_name = frame_name.replace(",","")
    name_list.append(frame_name)
    frame = pd.read_table(name, sep= '\t')
    #reformat column names
    columns = frame.columns
    columns = [x.lower().replace("*","").replace("-","_").replace(" ","_") for x in columns]
    frame.columns = columns
    #create a variable named the frame_name
    vars()[frame_name] = frame
# Out:
# /Users/agswigart/anaconda/envs/myenv/lib/python2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %% [markdown]
# # Functions

# %%
#function that calculates the number of features available in a dataframe (the # rows divided by # of jobs)
def feature(dataframe):
    return len(dataframe)/len(dataframe.onet_soc_code.unique())

# %% [markdown]
# # Data Filtering

# %% [markdown]
# ## Abilities

# %%
#In abilities, we only want to keep the rows where scale_id == 'IM'
abilities_final = abilities[abilities.scale_id == 'IM']

# %%
len(abilities_final)
# Out:
# 47996

# %%
feature(abilities_final)
# Out:
# 52

# %% [markdown]
# ## Knowledge

# %%
#In knowledge, we only want to keep the rows where scale_id == 'IM'
knowledge_final = knowledge[knowledge.scale_id == 'IM']

# %%
len(knowledge_final)
# Out:
# 30459

# %%
feature(knowledge_final)
# Out:
# 33

# %% [markdown]
# ## Interests

# %%
#In interests, we only want to keep rows where scale_id == 'OI'
interests_final = interests[interests.scale_id == 'OI']

# %%
len(interests_final)
# Out:
# 5844

# %%
feature(interests_final)
# Out:
# 6

# %%
interests_final['domain'] = 'Interests'
interests_final.head()
# Out:
#   onet_soc_code element_id   element_name scale_id  data_value     date  \
# 0    11-1011.00    1.B.1.a      Realistic       OI        1.33  06/2008
# 1    11-1011.00    1.B.1.b  Investigative       OI        2.00  06/2008
# 2    11-1011.00    1.B.1.c       Artistic       OI        2.67  06/2008
# 3    11-1011.00    1.B.1.d         Social       OI        3.67  06/2008
# 4    11-1011.00    1.B.1.e   Enterprising       OI        7.00  06/2008
#
#   domain_source     domain
# 0       Analyst  Interests
# 1       Analyst  Interests
# 2       Analyst  Interests
# 3       Analyst  Interests
# 4       Analyst  Interests
#
# [5 rows x 8 columns]

# %%
interests_pt = interests_final.pivot_table('data_value',
                                           rows = 'onet_soc_code',
                                           cols = ['domain', 'element_name'],
                                           aggfunc = 'sum')
interests_pt.head()
# Out:
# domain         Interests                                             \
# element_name    Artistic  Conventional  Enterprising  Investigative
# onet_soc_code
# 11-1011.00          2.67          5.33             7           2.00
# 11-1011.03          2.67          4.33             7           4.33
# 11-1021.00          1.00          3.67             7           1.33
# 11-1031.00          3.67          3.00             7           3.67
# 11-2011.00          5.33          4.67             7           2.00
#
# domain
# element_name   Realistic  Social
# onet_soc_code
# 11-1011.00          1.33    3.67
# 11-1011.03          1.00    2.33
# 11-1021.00          1.33    3.33
# 11-1031.00          1.00    4.67
# 11-2011.00          1.67    2.33
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Job Zones

# %%
#we do not need to do anything to job_zones
job_zones_final = job_zones

# %%
len(job_zones_final)
# Out:
# 924

# %%
feature(job_zones_final)
# Out:
# 1

# %%
job_zones_final.head()
# Out:
#   onet_soc_code  job_zone     date domain_source
# 0    11-1011.00         5  06/2006       Analyst
# 1    11-1011.03         5  07/2013       Analyst
# 2    11-1021.00         3  06/2008       Analyst
# 3    11-1031.00         4  06/2008       Analyst
# 4    11-2011.00         4  06/2010       Analyst
#
# [5 rows x 4 columns]

# %%
job_zones_final['domain'] = 'Job_Zones'
job_zones_final['element_name'] = 'job_zone'
job_zones_pt = job_zones_final.pivot_table('job_zone',
                                           rows = 'onet_soc_code',
                                           cols = ['domain', 'element_name'],
                                           aggfunc = 'sum')
job_zones_pt.head()
# Out:
# domain         Job_Zones
# element_name    job_zone
# onet_soc_code
# 11-1011.00             5
# 11-1011.03             5
# 11-1021.00             3
# 11-1031.00             4
# 11-2011.00             4
#
# [5 rows x 1 columns]

# %% [markdown]
# ## Skills

# %%
#for skills, we only want to keep rows where scale_id == "IM"
skills_final = skills[skills.scale_id == 'IM']

# %%
len(skills_final)
# Out:
# 32305

# %%
feature(skills_final)
# Out:
# 35

# %%
skills_final.head()
# Out:
#   onet_soc_code element_id           element_name scale_id  data_value  n  \
# 0    11-1011.00    2.A.1.a  Reading Comprehension       IM        4.38  8
# 2    11-1011.00    2.A.1.b       Active Listening       IM        4.38  8
# 4    11-1011.00    2.A.1.c                Writing       IM        4.12  8
# 6    11-1011.00    2.A.1.d               Speaking       IM        4.38  8
# 8    11-1011.00    2.A.1.e            Mathematics       IM        3.00  8
#
#   standard_error lower_ci_bound upper_ci_bound recommend_suppress  \
# 0           0.18           4.02           4.73                  N
# 2           0.18           4.02           4.73                  N
# 4           0.23           3.68           4.57                  N
# 6           0.18           4.02           4.73                  N
# 8           0.19           2.63           3.37                  N
#
#   not_relevant     date domain_source
# 0          n/a  06/2010       Analyst
# 2          n/a  06/2010       Analyst
# 4          n/a  06/2010       Analyst
# 6          n/a  06/2010       Analyst
# 8          n/a  06/2010       Analyst
#
# [5 rows x 13 columns]

# %%
skills_final['domain'] = 'Skills'
skills_pt = skills_final.pivot_table('data_value',
                                     rows = 'onet_soc_code',
                                     cols = ['domain', 'element_name'],
                                     aggfunc = 'sum')
skills_pt.head()
# Out:
# domain                  Skills                                             \
# element_name   Active Learning  Active Listening  Complex Problem Solving
# onet_soc_code
# 11-1011.00                4.00              4.38                     4.50
# 11-1011.03                3.50              3.88                     4.00
# 11-1021.00                3.50              4.00                     3.50
# 11-2011.00                3.25              4.00                     3.50
# 11-2021.00                3.50              3.88                     3.38
#
# domain                                                                 \
# element_name   Coordination  Critical Thinking  Equipment Maintenance
# onet_soc_code
# 11-1011.00             4.25               4.38                      1
# 11-1011.03             3.62               4.00                      1
# 11-1021.00             3.62               3.88                      1
# 11-2011.00             3.50               3.75                      1
# 11-2021.00             3.50               3.88                      1
#
# domain                                                         \
# element_name   Equipment Selection  Installation  Instructing
# onet_soc_code
# 11-1011.00                    1.00          1.00         3.25
# 11-1011.03                    1.12          1.00         3.25
# 11-1021.00                    1.25          1.12         3.12
# 11-2011.00                    1.25          1.00         2.88
# 11-2021.00                    1.00          1.00         3.12
#
# domain                                                            \
# element_name   Judgment and Decision Making  Learning Strategies
# onet_soc_code
# 11-1011.00                             4.50                 3.38
# 11-1011.03                             3.75                 3.38
# 11-1021.00                             3.50                 2.75
# 11-2011.00                             3.75                 2.75
# 11-2021.00                             3.62                 3.00
#
# domain                                            \
# element_name   Management of Financial Resources
# onet_soc_code
# 11-1011.00                                  4.12
# 11-1011.03                                  2.62
# 11-1021.00                                  2.88
# 11-2011.00                                  2.88
# 11-2021.00                                  2.88
#
# domain                                           \
# element_name   Management of Material Resources
# onet_soc_code
# 11-1011.00                                 3.62
# 11-1011.03                                 2.38
# 11-1021.00                                 3.12
# 11-2011.00                                 2.50
# 11-2021.00                                 2.38
#
# domain                                                                     \
# element_name   Management of Personnel Resources  Mathematics  Monitoring
# onet_soc_code
# 11-1011.00                                  4.25         3.00        4.12
# 11-1011.03                                  3.38         2.75        3.62
# 11-1021.00                                  3.38         2.25        3.75
# 11-2011.00                                  3.12         3.00        3.25
# 11-2021.00                                  3.38         2.75        3.62
#
# domain                                                                   \
# element_name   Negotiation  Operation Monitoring  Operation and Control
# onet_soc_code
# 11-1011.00            4.00                  2.25                   1.88
# 11-1011.03            2.88                  2.25                   1.62
# 11-1021.00            3.50                  2.88                   2.12
# 11-2011.00            3.38                  1.62                   1.25
# 11-2021.00            3.25                  2.00                   1.00
#
# domain
# element_name   Operations Analysis
# onet_soc_code
# 11-1011.00                    3.50 ...
# 11-1011.03                    2.62 ...
# 11-1021.00                    3.25 ...
# 11-2011.00                    2.88 ...
# 11-2021.00                    3.50 ...
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Work Activities

# %%
#for work activities, we only want to keep rows where scale_id == 'IM'
work_activities_final = work_activities[work_activities.scale_id == 'IM']

# %%
len(work_activities_final)
# Out:
# 37843

# %%
feature(work_activities_final)
# Out:
# 41

# %%
work_activities_final['domain'] = 'Work_Activities'
work_activities_pt = work_activities_final.pivot_table('data_value',
                                     rows = 'onet_soc_code',
                                     cols = ['domain', 'element_name'],
                                     aggfunc = 'sum')
work_activities_pt.head()
# Out:
# domain                       Work_Activities                                   \
# element_name   Analyzing Data or Information  Assisting and Caring for Others
# onet_soc_code
# 11-1011.00                              4.19                             2.22
# 11-1011.03                              3.85                             2.23
# 11-1021.00                              3.49                             3.08
# 11-2011.00                              2.81                             2.10
# 11-2021.00                              3.52                             2.40
#
# domain                                         \
# element_name   Coaching and Developing Others
# onet_soc_code
# 11-1011.00                               3.91
# 11-1011.03                               3.64
# 11-1021.00                               3.41
# 11-2011.00                               2.68
# 11-2021.00                               3.54
#
# domain                                                          \
# element_name   Communicating with Persons Outside Organization
# onet_soc_code
# 11-1011.00                                                4.62
# 11-1011.03                                                4.46
# 11-1021.00                                                3.83
# 11-2011.00                                                4.56
# 11-2021.00                                                4.60
#
# domain                                                                 \
# element_name   Communicating with Supervisors, Peers, or Subordinates
# onet_soc_code
# 11-1011.00                                                  4.75
# 11-1011.03                                                  4.58
# 11-1021.00                                                  3.74
# 11-2011.00                                                  4.28
# 11-2021.00                                                  4.58
#
# domain                                             \
# element_name   Controlling Machines and Processes
# onet_soc_code
# 11-1011.00                                   1.32
# 11-1011.03                                   1.36
# 11-1021.00                                   1.99
# 11-2011.00                                   2.22
# 11-2021.00                                   1.32
#
# domain                                                         \
# element_name   Coordinating the Work and Activities of Others
# onet_soc_code
# 11-1011.00                                               4.00
# 11-1011.03                                               3.96
# 11-1021.00                                               4.09
# 11-2011.00                                               3.06
# 11-2021.00                                               3.96
#
# domain                                               \
# element_name   Developing Objectives and Strategies
# onet_soc_code
# 11-1011.00                                     4.63
# 11-1011.03                                     4.31
# 11-1021.00                                     3.22
# 11-2011.00                                     3.68
# 11-2021.00                                     4.04
#
# domain                                        \
# element_name   Developing and Building Teams
# onet_soc_code
# 11-1011.00                              4.55
# 11-1011.03                              4.12
# 11-1021.00                              3.56
# 11-2011.00                              3.27
# 11-2021.00                              4.24
#
# domain                                            \
# element_name   Documenting/Recording Information
# onet_soc_code
# 11-1011.00                                  2.19
# 11-1011.03                                  3.44
# 11-1021.00                                  3.29
# 11-2011.00                                  3.30
# 11-2021.00                                  2.84
#
# domain                                                                                       \
# element_name   Drafting, Laying Out, and Specifying Technical Devices, Parts, and Equipment
# onet_soc_code
# 11-1011.00                                                  1.22
# 11-1011.03                                                  2.56
# 11-1021.00                                                  2.70
# 11-2011.00                                                  1.70
# 11-2021.00                                                  1.92
#
# domain                                                                   \
# element_name   Establishing and Maintaining Interpersonal Relationships
# onet_soc_code
# 11-1011.00                                                  4.64
# 11-1011.03                                                  4.28
# 11-1021.00                                                  3.82
# 11-2011.00                                                  4.04
# 11-2021.00                                                  4.40
#
# domain                                                                                          \
# element_name   Estimating the Quantifiable Characteristics of Products, Events, or Information
# onet_soc_code
# 11-1011.00                                                  2.68
# 11-1011.03                                                  3.31
# 11-1021.00                                                  3.36
# 11-2011.00                                                  3.07
# 11-2021.00                                                  3.16
#
# domain                                                                        \
# element_name   Evaluating Information to Determine Compliance with Standards
# onet_soc_code
# 11-1011.00                                                  3.50
# 11-1011.03                                                  4.12
# 11-1021.00                                                  3.54
# 11-2011.00                                                  2.50
# 11-2021.00                                                  2.84
#
# domain                              \
# element_name   Getting Information
# onet_soc_code
# 11-1011.00                    4.75
# 11-1011.03                    4.48
# 11-1021.00                    4.37
# 11-2011.00                    4.38
# 11-2021.00                    4.52
#
# domain                                                          \
# element_name   Guiding, Directing, and Motivating Subordinates
# onet_soc_code
# 11-1011.00                                                4.02
# 11-1011.03                                                3.88
# 11-1021.00                                                3.48
# 11-2011.00                                                2.72
# 11-2021.00                                                3.60
#
# domain                                      \
# element_name   Handling and Moving Objects
# onet_soc_code
# 11-1011.00                            1.48
# 11-1011.03                            1.62
# 11-1021.00                            2.53
# 11-2011.00                            1.86
# 11-2021.00                            1.52
#
# domain                                                   \
# element_name   Identifying Objects, Actions, and Events
# onet_soc_code
# 11-1011.00                                         3.64
# 11-1011.03                                         3.62
# 11-1021.00                                         3.65
# 11-2011.00                                         3.36
# 11-2021.00                                         3.84
#
# domain                                                        \
# element_name   Inspecting Equipment, Structures, or Material
# onet_soc_code
# 11-1011.00                                              1.49
# 11-1011.03                                              2.36
# 11-1021.00                                              3.36
# 11-2011.00                                              2.13
# 11-2021.00                                              1.84
#
# domain
# element_name   Interacting With Computers
# onet_soc_code
# 11-1011.00                           3.28 ...
# 11-1011.03                           4.32 ...
# 11-1021.00                           3.68 ...
# 11-2011.00                           4.08 ...
# 11-2021.00                           4.08 ...
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Work Context

# %%
#in work context, we only want to keep rows where scale_id == 'CX' or 'CT'
work_context_final = work_context[(work_context['scale_id'] == 'CX') | (work_context['scale_id'] == 'CT')]

# %%
len(work_context_final)
# Out:
# 52592

# %%
feature(work_context_final)
# Out:
# 56

# %%
work_context_final_CX = work_context_final[work_context_final['scale_id'] == 'CX']
work_context_final_CT = work_context_final[work_context_final['scale_id'] == 'CT']

# %%
work_context_final_CX['domain'] = 'Work_Context'
work_context_CX_pt = work_context_final_CX.pivot_table('data_value',
                                     rows = 'onet_soc_code',
                                     cols = ['domain', 'element_name'],
                                     aggfunc = 'sum')
work_context_CX_pt.head()
# Out:
# domain                 Work_Context                       \
# element_name   Consequence of Error  Contact With Others
# onet_soc_code
# 11-1011.00                     3.55                 4.84
# 11-1011.03                     2.35                 4.38
# 11-1021.00                     3.04                 4.76
# 11-2011.00                     2.06                 4.65
# 11-2021.00                     2.40                 4.64
#
# domain                                    \
# element_name   Coordinate or Lead Others
# onet_soc_code
# 11-1011.00                          4.32
# 11-1011.03                          4.12
# 11-1021.00                          4.20
# 11-2011.00                          4.12
# 11-2021.00                          3.72
#
# domain                                                \
# element_name   Cramped Work Space, Awkward Positions
# onet_soc_code
# 11-1011.00                                      1.47
# 11-1011.03                                      1.38
# 11-1021.00                                      1.32
# 11-2011.00                                      1.53
# 11-2021.00                                      1.21
#
# domain                                       \
# element_name   Deal With External Customers
# onet_soc_code
# 11-1011.00                             3.83
# 11-1011.03                             3.73
# 11-1021.00                             4.48
# 11-2011.00                             3.89
# 11-2021.00                             4.00
#
# domain                                                 \
# element_name   Deal With Physically Aggressive People
# onet_soc_code
# 11-1011.00                                       2.07
# 11-1011.03                                       1.04
# 11-1021.00                                       1.60
# 11-2011.00                                       1.29
# 11-2021.00                                       1.12
#
# domain                                                                     \
# element_name   Deal With Unpleasant or Angry People  Degree of Automation
# onet_soc_code
# 11-1011.00                                     3.92                  1.80
# 11-1011.03                                     2.38                  1.72
# 11-1021.00                                     3.39                  2.32
# 11-2011.00                                     2.73                  2.56
# 11-2021.00                                     2.56                  2.08
#
# domain                                                   \
# element_name   Electronic Mail  Exposed to Contaminants
# onet_soc_code
# 11-1011.00                5.00                     1.49
# 11-1011.03                4.96                     1.65
# 11-1021.00                4.26                     2.11
# 11-2011.00                5.00                     1.12
# 11-2021.00                5.00                     1.16
#
# domain                                           \
# element_name   Exposed to Disease or Infections
# onet_soc_code
# 11-1011.00                                 1.01
# 11-1011.03                                 1.12
# 11-1021.00                                 1.68
# 11-2011.00                                 1.17
# 11-2021.00                                 1.00
#
# domain                                          \
# element_name   Exposed to Hazardous Conditions
# onet_soc_code
# 11-1011.00                                1.47
# 11-1011.03                                1.23
# 11-1021.00                                1.40
# 11-2011.00                                1.03
# 11-2021.00                                1.04
#
# domain                                                                 \
# element_name   Exposed to Hazardous Equipment  Exposed to High Places
# onet_soc_code
# 11-1011.00                               1.49                    1.32
# 11-1011.03                               1.17                    1.50
# 11-1021.00                               1.68                    1.76
# 11-2011.00                               1.11                    1.12
# 11-2021.00                               1.12                    1.17
#
# domain                                                         \
# element_name   Exposed to Minor Burns, Cuts, Bites, or Stings
# onet_soc_code
# 11-1011.00                                               1.34
# 11-1011.03                                               1.15
# 11-1021.00                                               2.19
# 11-2011.00                                               1.31
# 11-2021.00                                               1.04
#
# domain                                                                \
# element_name   Exposed to Radiation  Exposed to Whole Body Vibration
# onet_soc_code
# 11-1011.00                     1.00                             1.44
# 11-1011.03                     1.08                             1.08
# 11-1021.00                     1.01                             1.15
# 11-2011.00                     1.00                             1.03
# 11-2021.00                     1.00                             1.00
#
# domain                                                  \
# element_name   Extremely Bright or Inadequate Lighting
# onet_soc_code
# 11-1011.00                                        1.35
# 11-1011.03                                        1.42
# 11-1021.00                                        1.79
# 11-2011.00                                        1.39
# 11-2021.00                                        1.20
#
# domain
# element_name   Face-to-Face Discussions  Freedom to Make Decisions
# onet_soc_code
# 11-1011.00                         5.00                       4.92 ...
# 11-1011.03                         4.76                       4.42 ...
# 11-1021.00                         4.60                       4.80 ...
# 11-2011.00                         4.56                       4.15 ...
# 11-2021.00                         4.84                       4.20 ...
#
# [5 rows x 55 columns]

# %%
work_context_final_CT['domain'] = 'Work_Context_Time'
work_context_CT_pt = work_context_final_CT.pivot_table('data_value',
                                     rows = 'onet_soc_code',
                                     cols = ['domain', 'element_name'],
                                     aggfunc = 'sum')
work_context_CT_pt.head()
# Out:
# domain                     Work_Context_Time
# element_name   Duration of Typical Work Week  Work Schedules
# onet_soc_code
# 11-1011.00                              2.91            1.00
# 11-1011.03                              2.77            1.35
# 11-1021.00                              2.67            1.37
# 11-2011.00                              2.51            1.04
# 11-2021.00                              2.68            1.28
#
# [5 rows x 2 columns]

# %% [markdown]
# ## Work Styles

# %%
#in work styles, we can keep everythin
work_styles_final = work_styles

# %%
len(work_styles_final)
# Out:
# 14752

# %%
feature(work_styles_final)
# Out:
# 16

# %%
work_styles_final['domain'] = 'Work_Styles'
work_styles_pt = work_styles_final.pivot_table('data_value',
                                     rows = 'onet_soc_code',
                                     cols = ['domain', 'element_name'],
                                     aggfunc = 'sum')
work_styles_pt.head()
# Out:
# domain                Work_Styles                            \
# element_name   Achievement/Effort  Adaptability/Flexibility
# onet_soc_code
# 11-1011.00                   4.66                      4.48
# 11-1011.03                   4.19                      4.23
# 11-1021.00                   4.07                      4.21
# 11-2011.00                   4.30                      4.54
# 11-2021.00                   4.24                      4.24
#
# domain                                                                       \
# element_name   Analytical Thinking  Attention to Detail  Concern for Others
# onet_soc_code
# 11-1011.00                    4.24                 4.26                3.95
# 11-1011.03                    4.31                 4.12                3.48
# 11-1021.00                    4.22                 4.52                3.96
# 11-2011.00                    4.16                 4.70                3.93
# 11-2021.00                    3.84                 4.48                3.72
#
# domain                                                               \
# element_name   Cooperation  Dependability  Independence  Initiative
# onet_soc_code
# 11-1011.00            4.42           4.67          4.63        4.79
# 11-1011.03            4.32           4.23          4.27        4.60
# 11-1021.00            4.26           4.73          3.96        4.36
# 11-2011.00            4.40           4.74          4.08        4.71
# 11-2021.00            4.44           4.56          4.20        4.32
#
# domain                                                                       \
# element_name   Innovation  Integrity  Leadership  Persistence  Self Control
# onet_soc_code
# 11-1011.00           4.22       4.85        4.84         4.61          4.28
# 11-1011.03           4.38       4.58        4.64         4.31          4.00
# 11-1021.00           3.88       4.36        4.50         4.24          4.38
# 11-2011.00           4.51       4.66        4.23         4.23          4.42
# 11-2021.00           4.08       4.40        4.36         4.28          4.04
#
# domain
# element_name   Social Orientation  Stress Tolerance
# onet_soc_code
# 11-1011.00                   4.02              4.75
# 11-1011.03                   3.35              4.08
# 11-1021.00                   3.56              4.35
# 11-2011.00                   3.99              4.39
# 11-2021.00                   3.88              4.20
#
# [5 rows x 16 columns]

# %% [markdown]
# ## Work Values

# %%
#in work values, we want to only keep rows where scale_id == 'EX'
work_values_final = work_values[work_values.scale_id == 'EX']

# %%
len(work_values_final)
# Out:
# 5844

# %%
feature(work_values_final)
# Out:
# 6

# %%
work_values_final['domain'] = 'Work_Values'
work_values_pt = work_values_final.pivot_table('data_value',
                                     rows = 'onet_soc_code',
                                     cols = ['domain', 'element_name'],
                                     aggfunc = 'sum')
work_values_pt.head()
# Out:
# domain         Work_Values                                                     \
# element_name   Achievement  Independence  Recognition  Relationships  Support
# onet_soc_code
# 11-1011.00            6.33          7.00         7.00           5.00     5.33
# 11-1011.03            6.67          6.67         6.00           5.00     3.33
# 11-1021.00            5.33          6.00         5.67           6.33     4.67
# 11-1031.00            5.33          5.00         5.00           5.67     4.00
# 11-2011.00            5.33          5.33         5.33           5.00     4.00
#
# domain
# element_name   Working Conditions
# onet_soc_code
# 11-1011.00                   6.33
# 11-1011.03                   6.33
# 11-1021.00                   6.00
# 11-1031.00                   4.33
# 11-2011.00                   5.33
#
# [5 rows x 6 columns]

# %%
occupation_data['element_name'] = "title"
occupation_data['domain'] = 'Occupation'
occ_data_pt = occupation_data.pivot_table('title',
                                     rows = 'onet_soc_code',
                                     cols = ['domain', 'element_name'],
                                     aggfunc = 'sum')


#combined_df = combined_df.rename(columns=lambda x: x.replace(' ', '_'))
occ_data_pt.Occupation.title = occ_data_pt.Occupation.title.apply(lambda x: x.replace(' ', '_'))
occ_data_pt.Occupation.title = occ_data_pt.Occupation.title.apply(lambda x: x.replace('/', '_'))
occ_data_pt.Occupation.title = occ_data_pt.Occupation.title.apply(lambda x: x.replace(',', '_'))


occ_data_pt.tail()
len(set(occ_data_pt.index))
# Out:
# /Users/agswigart/anaconda/envs/myenv/lib/python2.7/site-packages/pandas/core/generic.py:1830: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self[name] = value
# 1110

# %%
domain_pt_list = [interests_pt, job_zones_pt, skills_pt, work_activities_pt, work_context_CX_pt, work_context_CT_pt, work_styles_pt, work_values_pt]

combined_df = pd.concat(domain_pt_list, axis=1)

combined_df = pd.merge(occ_data_pt, combined_df, left_index = True, right_index = True)

combined_df.head()
# Out:
# domain                                 Occupation  Interests                \
# element_name                                title   Artistic  Conventional
# 11-1011.00                       Chief_Executives       2.67          5.33
# 11-1011.03          Chief_Sustainability_Officers       2.67          4.33
# 11-1021.00        General_and_Operations_Managers       1.00          3.67
# 11-1031.00                            Legislators       3.67          3.00
# 11-2011.00    Advertising_and_Promotions_Managers       5.33          4.67
#
# domain                                                        Job_Zones  \
# element_name  Enterprising  Investigative  Realistic  Social   job_zone
# 11-1011.00               7           2.00       1.33    3.67          5
# 11-1011.03               7           4.33       1.00    2.33          5
# 11-1021.00               7           1.33       1.33    3.33          3
# 11-1031.00               7           3.67       1.00    4.67          4
# 11-2011.00               7           2.00       1.67    2.33          4
#
# domain                 Skills                                             \
# element_name  Active Learning  Active Listening  Complex Problem Solving
# 11-1011.00               4.00              4.38                      4.5
# 11-1011.03               3.50              3.88                      4.0
# 11-1021.00               3.50              4.00                      3.5
# 11-1031.00                NaN               NaN                      NaN
# 11-2011.00               3.25              4.00                      3.5
#
# domain                                                                \
# element_name  Coordination  Critical Thinking  Equipment Maintenance
# 11-1011.00            4.25               4.38                      1
# 11-1011.03            3.62               4.00                      1
# 11-1021.00            3.62               3.88                      1
# 11-1031.00             NaN                NaN                    NaN
# 11-2011.00            3.50               3.75                      1
#
# domain                                                        \
# element_name  Equipment Selection  Installation  Instructing
# 11-1011.00                   1.00          1.00         3.25
# 11-1011.03                   1.12          1.00         3.25
# 11-1021.00                   1.25          1.12         3.12
# 11-1031.00                    NaN           NaN          NaN
# 11-2011.00                   1.25          1.00         2.88
#
# domain                                                           \
# element_name  Judgment and Decision Making  Learning Strategies
# 11-1011.00                            4.50                 3.38
# 11-1011.03                            3.75                 3.38
# 11-1021.00                            3.50                 2.75
# 11-1031.00                             NaN                  NaN
# 11-2011.00                            3.75                 2.75
#
# domain
# element_name  Management of Financial Resources
# 11-1011.00                                 4.12 ...
# 11-1011.03                                 2.62 ...
# 11-1021.00                                 2.88 ...
# 11-1031.00                                  NaN ...
# 11-2011.00                                 2.88 ...
#
# [5 rows x 163 columns]

# %%
# Remove spaces in element names
combined_df = combined_df.rename(columns=lambda x: x.replace(' ', '_'))

# combined_df.fillna(0, inplace=True)

# %%
combined_df.head()
# Out:
# domain                                 Occupation  Interests                \
# element_name                                title   Artistic  Conventional
# 11-1011.00                       Chief_Executives       2.67          5.33
# 11-1011.03          Chief_Sustainability_Officers       2.67          4.33
# 11-1021.00        General_and_Operations_Managers       1.00          3.67
# 11-1031.00                            Legislators       3.67          3.00
# 11-2011.00    Advertising_and_Promotions_Managers       5.33          4.67
#
# domain                                                        Job_Zones  \
# element_name  Enterprising  Investigative  Realistic  Social   job_zone
# 11-1011.00               7           2.00       1.33    3.67          5
# 11-1011.03               7           4.33       1.00    2.33          5
# 11-1021.00               7           1.33       1.33    3.33          3
# 11-1031.00               7           3.67       1.00    4.67          4
# 11-2011.00               7           2.00       1.67    2.33          4
#
# domain                 Skills                                             \
# element_name  Active_Learning  Active_Listening  Complex_Problem_Solving
# 11-1011.00               4.00              4.38                      4.5
# 11-1011.03               3.50              3.88                      4.0
# 11-1021.00               3.50              4.00                      3.5
# 11-1031.00                NaN               NaN                      NaN
# 11-2011.00               3.25              4.00                      3.5
#
# domain                                                                \
# element_name  Coordination  Critical_Thinking  Equipment_Maintenance
# 11-1011.00            4.25               4.38                      1
# 11-1011.03            3.62               4.00                      1
# 11-1021.00            3.62               3.88                      1
# 11-1031.00             NaN                NaN                    NaN
# 11-2011.00            3.50               3.75                      1
#
# domain                                                        \
# element_name  Equipment_Selection  Installation  Instructing
# 11-1011.00                   1.00          1.00         3.25
# 11-1011.03                   1.12          1.00         3.25
# 11-1021.00                   1.25          1.12         3.12
# 11-1031.00                    NaN           NaN          NaN
# 11-2011.00                   1.25          1.00         2.88
#
# domain                                                           \
# element_name  Judgment_and_Decision_Making  Learning_Strategies
# 11-1011.00                            4.50                 3.38
# 11-1011.03                            3.75                 3.38
# 11-1021.00                            3.50                 2.75
# 11-1031.00                             NaN                  NaN
# 11-2011.00                            3.75                 2.75
#
# domain
# element_name  Management_of_Financial_Resources
# 11-1011.00                                 4.12 ...
# 11-1011.03                                 2.62 ...
# 11-1021.00                                 2.88 ...
# 11-1031.00                                  NaN ...
# 11-2011.00                                 2.88 ...
#
# [5 rows x 163 columns]

# %%
def normalize(series):
    maximum = series.max()
    minimum = series.min()
    return [(item - minimum) / (maximum - minimum) for item in series]

# %%
normed_df = combined_df.copy()
normed_df.iloc[:,1:] = normed_df.iloc[:,1:].apply(normalize)
normed_df.head()
# Out:
# domain                                 Occupation  Interests                \
# element_name                                title   Artistic  Conventional
# 11-1011.00                       Chief_Executives   0.278333      0.721667
# 11-1011.03          Chief_Sustainability_Officers   0.278333      0.555000
# 11-1021.00        General_and_Operations_Managers   0.000000      0.445000
# 11-1031.00                            Legislators   0.445000      0.333333
# 11-2011.00    Advertising_and_Promotions_Managers   0.721667      0.611667
#
# domain                                                          Job_Zones  \
# element_name  Enterprising  Investigative  Realistic    Social   job_zone
# 11-1011.00               1       0.166667   0.055000  0.445000       1.00
# 11-1011.03               1       0.555000   0.000000  0.221667       1.00
# 11-1021.00               1       0.055000   0.055000  0.388333       0.50
# 11-1031.00               1       0.445000   0.000000  0.611667       0.75
# 11-2011.00               1       0.166667   0.111667  0.221667       0.75
#
# domain                 Skills                                             \
# element_name  Active_Learning  Active_Listening  Complex_Problem_Solving
# 11-1011.00           0.949367             0.800                      1.0
# 11-1011.03           0.738397             0.600                      0.8
# 11-1021.00           0.738397             0.648                      0.6
# 11-1031.00                NaN               NaN                      NaN
# 11-2011.00           0.632911             0.648                      0.6
#
# domain                                                                \
# element_name  Coordination  Critical_Thinking  Equipment_Maintenance
# 11-1011.00        1.000000              0.852                      0
# 11-1011.03        0.720000              0.700                      0
# 11-1021.00        0.720000              0.652                      0
# 11-1031.00             NaN                NaN                    NaN
# 11-2011.00        0.666667              0.600                      0
#
# domain                                                        \
# element_name  Equipment_Selection  Installation  Instructing
# 11-1011.00               0.000000      0.000000     0.621547
# 11-1011.03               0.040000      0.000000     0.621547
# 11-1021.00               0.083333      0.038462     0.585635
# 11-1031.00                    NaN           NaN          NaN
# 11-2011.00               0.083333      0.000000     0.519337
#
# domain                                                           \
# element_name  Judgment_and_Decision_Making  Learning_Strategies
# 11-1011.00                             1.0             0.693252
# 11-1011.03                             0.7             0.693252
# 11-1021.00                             0.6             0.500000
# 11-1031.00                             NaN                  NaN
# 11-2011.00                             0.7             0.500000
#
# domain
# element_name  Management_of_Financial_Resources
# 11-1011.00                             1.000000 ...
# 11-1011.03                             0.519231 ...
# 11-1021.00                             0.602564 ...
# 11-1031.00                                  NaN ...
# 11-2011.00                             0.602564 ...
#
# [5 rows x 163 columns]

# %% [markdown]
# Visualizing the Features

# %%
from math import floor,ceil
def draw_histogram(domain_frame):
    fig, axes = plt.subplots(nrows=int((ceil(float(len(domain_frame.columns))/3.0))), ncols=3, figsize = (12,len(domain_frame.columns)))
    plt.subplots_adjust(hspace = 0.4)
    for i,column_name in enumerate(domain_frame.columns):
        row = int(floor(i/3))
        column = i % 3
        domain_frame[column_name].hist(bins=10, ax=axes[row,column]); axes[row,column].set_title(column_name); axes[row,column].set_ylim([0,500])

# %%
# draw_histogram(combined_df.Job_Zones)
# normed_df.Interests.Investigative.hist(bins=10)
draw_histogram(normed_df.Interests)

# %%
draw_histogram(normed_df.Skills)

# %%
draw_histogram(normed_df.Work_Activities)

# %%
draw_histogram(normed_df.Work_Context)

# %%
draw_histogram(normed_df.Work_Context_Time)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-ab67bc215f7f> in <module>()
# ----> 1 draw_histogram(normed_df.Work_Context_Time)
#
# <ipython-input-51-e444ff717fe3> in draw_histogram(domain_frame)
#       6         row = int(floor(i/3))
#       7         column = i % 3
# ----> 8         domain_frame[column_name].hist(bins=10, ax=axes[row,column]); axes[row,column].set_title(column_name); axes[row,column].set_ylim([0,500])
#
# IndexError: too many indices

# %%
draw_histogram(normed_df.Work_Styles)

# %%
draw_histogram(normed_df.Work_Values)

# %% [markdown]
# Correlation between Features

# %%
corr_df = normed_df.iloc[:,1:].corr()

# %%
corr_df.index = corr_df.index.droplevel(0)
corr_df.head()
# Out:
# domain         Interests                                             \
# element_name    Artistic  Conventional  Enterprising  Investigative
# element_name
# Artistic        1.000000     -0.401212      0.012268       0.201901
# Conventional   -0.401212      1.000000      0.267182      -0.149493
# Enterprising    0.012268      0.267182      1.000000      -0.311084
# Investigative   0.201901     -0.149493     -0.311084       1.000000
# Realistic      -0.388635     -0.137886     -0.550015      -0.050547
#
# domain                              Job_Zones           Skills  \
# element_name   Realistic    Social   job_zone  Active_Learning
# element_name
# Artistic       -0.388635  0.311364   0.427659         0.360623
# Conventional   -0.137886 -0.239040  -0.177788        -0.163082
# Enterprising   -0.550015  0.191897   0.139388         0.237040
# Investigative  -0.050547  0.061720   0.643559         0.572187
# Realistic       1.000000 -0.569939  -0.536989        -0.500476
#
# domain                                                                  \
# element_name   Active_Listening  Complex_Problem_Solving  Coordination
# element_name
# Artistic               0.292641                 0.245882      0.188951
# Conventional          -0.000384                -0.126095     -0.092104
# Enterprising           0.446623                 0.199139      0.506449
# Investigative          0.360374                 0.617767      0.114631
# Realistic             -0.664910                -0.345526     -0.425227
#
# domain                                                                        \
# element_name   Critical_Thinking  Equipment_Maintenance  Equipment_Selection
# element_name
# Artistic                0.240592              -0.339151            -0.250277
# Conventional           -0.112272              -0.098427            -0.161965
# Enterprising            0.266822              -0.420746            -0.455691
# Investigative           0.588151              -0.064329             0.040445
# Realistic              -0.435737               0.663616             0.683996
#
# domain                                                                  \
# element_name   Installation  Instructing  Judgment_and_Decision_Making
# element_name
# Artistic          -0.179429     0.314698                      0.259137
# Conventional      -0.064627    -0.253891                     -0.144256
# Enterprising      -0.310320     0.184611                      0.304429
# Investigative      0.045447     0.382763                      0.495419
# Realistic          0.421077    -0.419841                     -0.409970
#
# domain                                                                 \
# element_name   Learning_Strategies  Management_of_Financial_Resources
# element_name
# Artistic                  0.340943                           0.084552
# Conventional             -0.230510                           0.052377
# Enterprising              0.169215                           0.412286
# Investigative             0.439133                           0.151122
# Realistic                -0.453541                          -0.203513
#
# domain
# element_name   Management_of_Material_Resources
# element_name
# Artistic                               0.085508 ...
# Conventional                          -0.044017 ...
# Enterprising                           0.261025 ...
# Investigative                          0.167033 ...
# Realistic                             -0.025298 ...
#
# [5 rows x 162 columns]

# %%
corr_df.columns = corr_df.columns.droplevel(0)
corr_df.head()
# Out:
# element_name   Artistic  Conventional  Enterprising  Investigative  Realistic  \
# element_name
# Artistic       1.000000     -0.401212      0.012268       0.201901  -0.388635
# Conventional  -0.401212      1.000000      0.267182      -0.149493  -0.137886
# Enterprising   0.012268      0.267182      1.000000      -0.311084  -0.550015
# Investigative  0.201901     -0.149493     -0.311084       1.000000  -0.050547
# Realistic     -0.388635     -0.137886     -0.550015      -0.050547   1.000000
#
# element_name     Social  job_zone  Active_Learning  Active_Listening  \
# element_name
# Artistic       0.311364  0.427659         0.360623          0.292641
# Conventional  -0.239040 -0.177788        -0.163082         -0.000384
# Enterprising   0.191897  0.139388         0.237040          0.446623
# Investigative  0.061720  0.643559         0.572187          0.360374
# Realistic     -0.569939 -0.536989        -0.500476         -0.664910
#
# element_name   Complex_Problem_Solving  Coordination  Critical_Thinking  \
# element_name
# Artistic                      0.245882      0.188951           0.240592
# Conventional                 -0.126095     -0.092104          -0.112272
# Enterprising                  0.199139      0.506449           0.266822
# Investigative                 0.617767      0.114631           0.588151
# Realistic                    -0.345526     -0.425227          -0.435737
#
# element_name   Equipment_Maintenance  Equipment_Selection  Installation  \
# element_name
# Artistic                   -0.339151            -0.250277     -0.179429
# Conventional               -0.098427            -0.161965     -0.064627
# Enterprising               -0.420746            -0.455691     -0.310320
# Investigative              -0.064329             0.040445      0.045447
# Realistic                   0.663616             0.683996      0.421077
#
# element_name   Instructing  Judgment_and_Decision_Making  Learning_Strategies  \
# element_name
# Artistic          0.314698                      0.259137             0.340943
# Conventional     -0.253891                     -0.144256            -0.230510
# Enterprising      0.184611                      0.304429             0.169215
# Investigative     0.382763                      0.495419             0.439133
# Realistic        -0.419841                     -0.409970            -0.453541
#
# element_name   Management_of_Financial_Resources  \
# element_name
# Artistic                                0.084552
# Conventional                            0.052377
# Enterprising                            0.412286
# Investigative                           0.151122
# Realistic                              -0.203513
#
# element_name   Management_of_Material_Resources
# element_name
# Artistic                               0.085508 ...
# Conventional                          -0.044017 ...
# Enterprising                           0.261025 ...
# Investigative                          0.167033 ...
# Realistic                             -0.025298 ...
#
# [5 rows x 162 columns]

# %%
corr_pairs_list = []
for i in range(len(corr_df.index)):
    row_name = corr_df.index[i]
    for j in range(i + 1, len(corr_df.columns)):
        column_name = corr_df.columns[j]
        corr_pairs_list.append([row_name,column_name, corr_df.ix[i,j]])

# %%
corr_pairs_df = DataFrame(corr_pairs_list)

# %%
corr_pairs_df.sort(2)
# Out:
#                                                        0  \
# 12446                                 Spend_Time_Sitting
# 12448                                 Spend_Time_Sitting
# 12265            Spend_Time_Bending_or_Twisting_the_Body
# 8911              Performing_General_Physical_Activities
# 10586                                    Electronic_Mail
# 7753                         Handling_and_Moving_Objects
# 5861                                             Writing
# 8051                          Interacting_With_Computers
# 4486                               Reading_Comprehension
# 7717                         Handling_and_Moving_Objects
# 10990     Exposed_to_Minor_Burns,_Cuts,_Bites,_or_Stings
# 10593                                    Electronic_Mail
# 12376  Spend_Time_Kneeling,_Crouching,_Stooping,_or_C...
# 10592                                    Electronic_Mail
# 668                                            Realistic
# 5868                                             Writing
# 11738                Indoors,_Environmentally_Controlled
# 5133                                            Speaking
# 5797                                             Writing
# 11098                    Exposed_to_Whole_Body_Vibration
# 4422                               Reading_Comprehension
# 10561                                    Electronic_Mail
# 11663                    In_an_Open_Vehicle_or_Equipment
# 4493                               Reading_Comprehension
# 641                                            Realistic
# 8618   Operating_Vehicles,_Mechanized_Devices,_or_Equ...
# 7687                         Handling_and_Moving_Objects
# 8057                          Interacting_With_Computers
# 12340            Spend_Time_Keeping_or_Regaining_Balance
# 1380                                    Active_Listening
# 8875              Performing_General_Physical_Activities
# 7999                          Interacting_With_Computers
# 6325     Communicating_with_Persons_Outside_Organization
# 1066                                            job_zone
# 10660                            Exposed_to_Contaminants
# 11832                                  Letters_and_Memos
# 10844                     Exposed_to_Hazardous_Equipment
# 10594                                    Electronic_Mail
# 674                                            Realistic
# 686                                            Realistic
# 8026                          Interacting_With_Computers
# 10556                                    Electronic_Mail
# 5126                                            Speaking
# 12296            Spend_Time_Bending_or_Twisting_the_Body
# 1373                                    Active_Listening
# 5867                                             Writing
# 663                                            Realistic
# 5062                                            Speaking
# 12453                                 Spend_Time_Sitting
# 4434                               Reading_Comprehension
# 8053                          Interacting_With_Computers
# 10973     Exposed_to_Minor_Burns,_Cuts,_Bites,_or_Stings
# 1002                                            job_zone
# 4492                               Reading_Comprehension
# 11825                                  Letters_and_Memos
# 5836                                             Writing
# 12294            Spend_Time_Bending_or_Twisting_the_Body
# 5051                                            Speaking
# 4097                                          Persuasion
# 5809                                             Writing
#                                                      ...
#
#                                                        1         2
# 12446                                Spend_Time_Standing -0.967267
# 12448                     Spend_Time_Walking_and_Running -0.835168
# 12265                                 Spend_Time_Sitting -0.795219
# 8911                                  Spend_Time_Sitting -0.782129
# 10586            Spend_Time_Bending_or_Twisting_the_Body -0.773786
# 7753                                  Spend_Time_Sitting -0.751062
# 5861             Spend_Time_Bending_or_Twisting_the_Body -0.717948
# 8051             Spend_Time_Bending_or_Twisting_the_Body -0.717089
# 4486             Spend_Time_Bending_or_Twisting_the_Body -0.713159
# 7717                                     Electronic_Mail -0.711717
# 10990                                 Spend_Time_Sitting -0.711399
# 10593  Spend_Time_Using_Your_Hands_to_Handle,_Control... -0.705413
# 12376                                 Spend_Time_Sitting -0.703470
# 10592                                Spend_Time_Standing -0.699675
# 668                                             Speaking -0.697539
# 5868   Spend_Time_Using_Your_Hands_to_Handle,_Control... -0.695551
# 11738                      Very_Hot_or_Cold_Temperatures -0.688135
# 5133   Spend_Time_Using_Your_Hands_to_Handle,_Control... -0.687152
# 5797                         Handling_and_Moving_Objects -0.683033
# 11098                Indoors,_Environmentally_Controlled -0.680449
# 4422                         Handling_and_Moving_Objects -0.670271
# 10561     Exposed_to_Minor_Burns,_Cuts,_Bites,_or_Stings -0.667508
# 11663                Indoors,_Environmentally_Controlled -0.667292
# 4493   Spend_Time_Using_Your_Hands_to_Handle,_Control... -0.665916
# 641                                     Active_Listening -0.664910
# 8618                 Indoors,_Environmentally_Controlled -0.660575
# 7687                          Interacting_With_Computers -0.660367
# 8057                                 Spend_Time_Standing -0.659657
# 12340                                 Spend_Time_Sitting -0.655549
# 1380   Spend_Time_Using_Your_Hands_to_Handle,_Control... -0.652968
# 8875                                     Electronic_Mail -0.650777
# 7999              Performing_General_Physical_Activities -0.650413
# 6325               Pace_Determined_by_Speed_of_Equipment -0.650114
# 1066             Spend_Time_Bending_or_Twisting_the_Body -0.644585
# 10660                                 Spend_Time_Sitting -0.644513
# 11832  Spend_Time_Using_Your_Hands_to_Handle,_Control... -0.643299
# 10844                Indoors,_Environmentally_Controlled -0.641733
# 10594                     Spend_Time_Walking_and_Running -0.639322
# 674                                              Writing -0.638714
# 686    Establishing_and_Maintaining_Interpersonal_Rel... -0.634594
# 8026      Exposed_to_Minor_Burns,_Cuts,_Bites,_or_Stings -0.629980
# 10556                            Exposed_to_Contaminants -0.629270
# 5126             Spend_Time_Bending_or_Twisting_the_Body -0.627783
# 12296                                        Recognition -0.626270
# 1373             Spend_Time_Bending_or_Twisting_the_Body -0.623239
# 5867                                 Spend_Time_Standing -0.621393
# 663                                Reading_Comprehension -0.620490
# 5062                         Handling_and_Moving_Objects -0.619313
# 12453  Wear_Common_Protective_or_Safety_Equipment_suc... -0.617690
# 4434              Performing_General_Physical_Activities -0.617219
# 8053             Spend_Time_Keeping_or_Regaining_Balance -0.616856
# 10973                Indoors,_Environmentally_Controlled -0.616442
# 1002                         Handling_and_Moving_Objects -0.616243
# 4492                                 Spend_Time_Standing -0.615121
# 11825            Spend_Time_Bending_or_Twisting_the_Body -0.615008
# 5836      Exposed_to_Minor_Burns,_Cuts,_Bites,_or_Stings -0.614475
# 12294                                        Achievement -0.614046
# 5051                  Controlling_Machines_and_Processes -0.613475
# 4097   Spend_Time_Using_Your_Hands_to_Handle,_Control... -0.612960
# 5809              Performing_General_Physical_Activities -0.611421
#                                                      ...       ...
#
# [13041 rows x 3 columns]

# %%
corr_pairs_df.sort(2, ascending=False)
# Out:
#                                                     0  \
# 1884                            Equipment_Maintenance
# 5166                                 Systems_Analysis
# 13027                                     Achievement
# 4405                            Reading_Comprehension
# 2032                              Equipment_Selection
# 1866                            Equipment_Maintenance
# 3588                             Operation_Monitoring
# 2311                                      Instructing
# 10922                          Exposed_to_High_Places
# 1928                            Equipment_Maintenance
# 13037                                     Recognition
# 7696                      Handling_and_Moving_Objects
# 4569                                        Repairing
# 1286                                 Active_Listening
# 13030                                     Achievement
# 3453                                      Negotiation
# 1414                          Complex_Problem_Solving
# 1419                          Complex_Problem_Solving
# 2745                Management_of_Financial_Resources
# 3603                             Operation_Monitoring
# 1720                                Critical_Thinking
# 1893                            Equipment_Maintenance
# 4273                         Quality_Control_Analysis
# 4534                                        Repairing
# 1109                                  Active_Learning
# 2041                              Equipment_Selection
# 3746                            Operation_and_Control
# 1440                          Complex_Problem_Solving
# 6601   Coordinating_the_Work_and_Activities_of_Others
# 12821                              Achievement/Effort
# 5930                    Analyzing_Data_or_Information
# 2076                              Equipment_Selection
# 12953                                      Initiative
# 12481                             Spend_Time_Standing
# 1114                                  Active_Learning
# 6513               Controlling_Machines_and_Processes
# 5694                                  Troubleshooting
# 13026                                     Achievement
# 1107                                  Active_Learning
# 13034                                    Independence
# 1439                          Complex_Problem_Solving
# 1100                                         job_zone
# 8020                       Interacting_With_Computers
# 1115                                  Active_Learning
# 11913                    Outdoors,_Exposed_to_Weather
# 1102                                         job_zone
# 5830                                          Writing
# 11388                    Frequency_of_Decision_Making
# 4455                            Reading_Comprehension
# 1865                                Critical_Thinking
# 12897                              Concern_for_Others
# 12263         Spend_Time_Bending_or_Twisting_the_Body
# 1862                                Critical_Thinking
# 1256                                  Active_Learning
# 6174                   Coaching_and_Developing_Others
# 11615             In_an_Enclosed_Vehicle_or_Equipment
# 13031                                    Independence
# 8906           Performing_General_Physical_Activities
# 1139                                  Active_Learning
# 2476                     Judgment_and_Decision_Making
#                                                   ...
#
#                                                        1         2
# 1884                                           Repairing  0.976774
# 5166                                  Systems_Evaluation  0.943016
# 13027                                        Recognition  0.919637
# 4405                                             Writing  0.916252
# 2032                                           Repairing  0.909113
# 1866                                 Equipment_Selection  0.905916
# 3588                               Operation_and_Control  0.901321
# 2311                                 Learning_Strategies  0.896822
# 10922   Spend_Time_Climbing_Ladders,_Scaffolds,_or_Poles  0.894912
# 1928      Repairing_and_Maintaining_Mechanical_Equipment  0.892552
# 13037                                 Working_Conditions  0.889523
# 7696              Performing_General_Physical_Activities  0.888681
# 4569      Repairing_and_Maintaining_Mechanical_Equipment  0.887249
# 1286                                            Speaking  0.886562
# 13030                                 Working_Conditions  0.885633
# 3453                                          Persuasion  0.884341
# 1414                                   Critical_Thinking  0.876100
# 1419                        Judgment_and_Decision_Making  0.873171
# 2745                    Management_of_Material_Resources  0.868843
# 3603                                     Troubleshooting  0.865452
# 1720                        Judgment_and_Decision_Making  0.863481
# 1893                                     Troubleshooting  0.863022
# 4273                                     Troubleshooting  0.861049
# 4534                                     Troubleshooting  0.860817
# 1109                                   Critical_Thinking  0.858779
# 2041                                     Troubleshooting  0.857719
# 3746                  Controlling_Machines_and_Processes  0.857358
# 1440                                  Systems_Evaluation  0.853486
# 6601                       Developing_and_Building_Teams  0.848110
# 12821                                        Persistence  0.847364
# 5930                              Processing_Information  0.844796
# 2076      Repairing_and_Maintaining_Mechanical_Equipment  0.844682
# 12953                                        Persistence  0.841958
# 12481                     Spend_Time_Walking_and_Running  0.841053
# 1114                        Judgment_and_Decision_Making  0.840695
# 6513      Repairing_and_Maintaining_Mechanical_Equipment  0.839191
# 5694      Repairing_and_Maintaining_Mechanical_Equipment  0.837864
# 13026                                       Independence  0.837742
# 1107                             Complex_Problem_Solving  0.837309
# 13034                                 Working_Conditions  0.835889
# 1439                                    Systems_Analysis  0.835821
# 1100                                         Achievement  0.835461
# 8020                                     Electronic_Mail  0.835297
# 1115                                 Learning_Strategies  0.835023
# 11913                              Outdoors,_Under_Cover  0.834886
# 1102                                         Recognition  0.832792
# 5830                                     Electronic_Mail  0.831127
# 11388  Impact_of_Decisions_on_Co-workers_or_Company_R...  0.830485
# 4455                                     Electronic_Mail  0.829915
# 1865                                  Working_Conditions  0.829546
# 12897                                 Social_Orientation  0.828631
# 12263  Spend_Time_Kneeling,_Crouching,_Stooping,_or_C...  0.824567
# 1862                                         Recognition  0.824394
# 1256                                         Recognition  0.823616
# 6174                        Training_and_Teaching_Others  0.823240
# 11615                       Outdoors,_Exposed_to_Weather  0.822343
# 13031                                        Recognition  0.821812
# 8906             Spend_Time_Bending_or_Twisting_the_Body  0.821150
# 1139                                             Writing  0.821125
# 2476                                  Systems_Evaluation  0.820151
#                                                      ...       ...
#
# [13041 rows x 3 columns]

# %%
normed_df_subset = normed_df.domain[['Interests', 'Skills', 'Knowledge']]
#corr_df_2 = normed_df.iloc[:,1:].corr()
